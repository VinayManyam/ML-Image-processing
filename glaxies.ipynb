# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (50,20)

df = pd.read_excel (r'data_final.xlsx', sheet_name='Sheet1')

#print (df)
dt = pd.DataFrame(df.to_numpy(),columns=['length', 'width', 'species'])
#ax1 = dt.plot.scatter(x='length',y='width',c='DarkBlue')
dt.plot.scatter(x='length',y='width',c='DarkBlue')
plt.savefig('test.png')
